# %% [markdown]
# # Kata 8

# %% [markdown]
# ## Exercise 1

# %%
planet = {
    'name': 'Mars',
    'moons': 2
}

# %%
print(f'{planet["name"]} has {planet["moons"]} moons ')
# Out:
# Mars has 2 moons

# %%
planet['circunference(km)'] = {
    'polar': 6752,
    'equatorial': 6792
}

# %%
print(f"{planet['name']}'s polar circunference is {planet['circunference(km)']['polar']}")
# Out:
# Mars's polar circunference is 6752

# %%
planet_moons = {
    'mercury': 0,
    'venus': 0,
    'earth': 1,
    'mars': 2,
    'jupiter': 79,
    'saturn': 82,
    'uranus': 27,
    'neptune': 14,
    'pluto': 5,
    'haumea': 2,
    'makemake': 1,
    'eris': 1
}

# %%
total_moons = sum(planet_moons.values())
print(total_moons)
# Out:
# 214

# %%
average = total_moons / len(planets.keys())

print(average)
# Out:
# 107.0

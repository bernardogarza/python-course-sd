# %% [markdown]
# # Kata 9

# %% [markdown]
# ## Exercise 1

# %%
def average_tanks(tank1, tank2, tank3):
    return average2([tank1, tank2, tank3])

# %%
average_tanks(20,30,50)
# Out:
# 33.333333333333336

# %%
def average2(val):
    return sum(val) / len(val)
average2([90, 25, 70])
# Out:
# 61.666666666666664

# %%
def mission_report(pre_launch_time, flight_time, destination, external_tank, main_tank):
    return f"Mission to {destination}\nTotal travel time: {pre_launch_time + flight_time} minutes\nTotal fuel left: {external_tank + main_tank}"
print(mission_report(14, 51, "moon", 200000, 300000))
# Out:
# Mission to moon
# Total travel time: 65 minutes
# Total fuel left: 500000

# %%
def mission_report(destination, *minutes, **fuel_reservoris):
    return f"Mission to {destination}\nTotal travel time: {sum(minutes)} minutes\nTotal fuel left: {sum(fuel_reservoris.values())}"
print(mission_report("moon", 10, 15, 51, main=300000, external=200000))
# Out:
# Mission to moon
# Total travel time: 76 minutes
# Total fuel left: 500000

# %%
def mission_report(destination, *minutes, **fuel_reservoirs):
    main_report = f"Mission to {destination}\nTotal travel time: {sum(minutes)} minutes\nTotal fuel left: {sum(fuel_reservoirs.values())}"
    for tank_name, gallons in fuel_reservoirs.items():
        main_report += f"{tank_name} tank -> {gallons} gallons left\n"
    return main_report;
print(mission_report("moon", 10, 15, 51, main=300000, external=200000))
# Out:
# Mission to moon
# Total travel time: 76 minutes
# Total fuel left: 500000main tank -> 300000 gallons left
# external tank -> 200000 gallons left
